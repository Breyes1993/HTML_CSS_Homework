# %%
import pandas

# %%
dataframe = pandas.read_csv('Weather_Data_Output.csv')
dataframe.head()
# Out:
#    Unnamed: 0     City  Cloudiness Country  Humidity    Lat  Max Temp  \
# 0           0   Chemal           0      RU        74  51.41     13.31
# 1           1   Chaman          88      AF        97  30.92     40.31
# 2           2  Bubaque           0      GW        94  11.28     77.39
# 3           3    Vaini           0      IN        85  15.34     56.96
# 4           4    Ambon          90      FR        93  47.55     54.00
#
#    Wind Speed
# 0        1.92
# 1        1.70
# 2        3.04
# 3        2.26
# 4       13.87

# %%
html_conversion = dataframe.to_html()
html_conversion
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>City</th>\n      <th>Cloudiness</th>\n      <th>Country</th>\n      <th>Humidity</th>\n      <th>Lat</th>\n      <th>Max Temp</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>Chemal</td>\n      <td>0</td>\n      <td>RU</td>\n      <td>74</td>\n      <td>51.41</td>\n      <td>13.31</td>\n      <td>1.92</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>Chaman</td>\n      <td>88</td>\n      <td>AF</td>\n      <td>97</td>\n      <td>30.92</td>\n      <td>40.31</td>\n      <td>1.70</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>Bubaque</td>\n      <td>0</td>\n      <td>GW</td>\n      <td>94</td>\n      <td>11.28</td>\n      <td>77.39</td>\n      <td>3.04</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>3</td>\n      <td>Vai
# ...

# %%
dataframe.to_html('Weather_Data.html')
